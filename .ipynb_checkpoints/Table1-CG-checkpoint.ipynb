# %%
# Set up: Install required packages, etc.
# import Pkg; Pkg.add("DataFrames")
# import Pkg; Pkg.add("CSV")
# import Pkg; Pkg.add("StatFiles")
import Pkg; Pkg.add("GLM")
import Pkg; Pkg.add("CovarianceMatrices")

# %%
# Load and clean data
using DataFrames, CSV, StatFiles
us_data = DataFrame(load("us_data_updated.dta"))
# Out:
# 12880×13 DataFrame
#    Row │ year    quarter  ind_for    timeseq  forecsource  fehor  forvar   ind ⋯
#        │ Int16?  Int8?    Float64?   Int16?   String?      Int8?  String?  Flo ⋯
# ───────┼────────────────────────────────────────────────────────────────────────
#      1 │   1968        4   0.452839       36  spf              0  cp           ⋯
#      2 │   1969        1  -1.26247        37  spf              0  cp
#      3 │   1969        2  -0.134128       38  spf              0  cp
#      4 │   1969        3  -1.26488        39  spf              0  cp
#      5 │   1969        4  -2.72118        40  spf              0  cp           ⋯
#      6 │   1970        1  -3.2218         41  spf              0  cp
#      7 │   1970        2  -2.09678        42  spf              0  cp
#      8 │   1970        3   1.37006        43  spf              0  cp
#      9 │   1970        4  -2.06353        44  spf              0  cp           ⋯
#     10 │   1971        1   5.09384        45  spf              0  cp
#     11 │   1971        2   4.71915        46  spf              0  cp
#    ⋮   │   ⋮        ⋮         ⋮         ⋮          ⋮         ⋮       ⋮         ⋱
#  12871 │   2012        2  10.1473        210  spf              4  ri
#  12872 │   2012        3  11.3807        211  spf              4  ri           ⋯
#  12873 │   2012        4  13.3419        212  spf              4  ri
#  12874 │   2013        1  13.1928        213  spf              4  ri
#  12875 │   2013        2  13.3501        214  spf              4  ri       mis
#  12876 │   2013        3  10.2887        215  spf              4  ri       mis ⋯
#  12877 │   2013        4  11.9055        216  spf              4  ri       mis
#  12878 │   2014        1  11.8276        217  spf              4  ri       mis
#  12879 │   2014        2  11.351         218  spf              4  ri       mis
#  12880 │   2014        3   9.95449       219  spf              4  ri       mis ⋯
#                                                 6 columns and 12859 rows omitted

# %%
us_data = filter(r -> r.forecsource == "spf" && r.forvar == "pi", us_data)

# using GLM, CovarianceMatrices
# ols = lm(@formula(ind_fe ~ ind_fr), us_data[us_data.fehor .== 3, :])
# coeftable(ols, vcov = vcov_hc(ols, HC1))
# Out:
# 920×13 DataFrame
#  Row │ year    quarter  ind_for        timeseq  forecsource  fehor  forvar   i ⋯
#      │ Int16?  Int8?    Float64?       Int16?   String?      Int8?  String?  F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │   1968        4        4.34525       36  spf              0  pi         ⋯
#    2 │   1969        1        3.82166       37  spf              0  pi
#    3 │   1969        2        2.97544       38  spf              0  pi
#    4 │   1969        3        4.67011       39  spf              0  pi
#    5 │   1969        4        4.67773       40  spf              0  pi         ⋯
#    6 │   1970        1        4.16887       41  spf              0  pi
#    7 │   1970        2        4.79495       42  spf              0  pi
#    8 │   1970        3        3.25644       43  spf              0  pi
#    9 │   1970        4        3.91268       44  spf              0  pi         ⋯
#   10 │   1971        1        3.9506        45  spf              0  pi
#   11 │   1971        2        3.80801       46  spf              0  pi
#   ⋮  │   ⋮        ⋮           ⋮           ⋮          ⋮         ⋮       ⋮       ⋱
#  911 │   2012        2        1.82579      210  spf              4  pi
#  912 │   2012        3        2.20706      211  spf              4  pi         ⋯
#  913 │   2012        4        1.95439      212  spf              4  pi
#  914 │   2013        1        1.90805      213  spf              4  pi
#  915 │   2013        2        1.81822      214  spf              4  pi       m
#  916 │   2013        3        2.02387      215  spf              4  pi       m ⋯
#  917 │   2013        4        1.90182      216  spf              4  pi       m
#  918 │   2014        1        1.89944      217  spf              4  pi       m
#  919 │   2014        2        1.76213      218  spf              4  pi       m
#  920 │   2014        3  missing            219  spf              4  pi       m ⋯
#                                                   6 columns and 899 rows omitted
